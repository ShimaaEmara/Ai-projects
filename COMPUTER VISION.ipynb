# %%
import cv2

# %%
                              # بيقرا الصوره بتاعتي علي شكل بيكسل ارقام يعني
                              #Im=image
                              #0= binary image
                              #defalut = RGB=BGR
img=cv2.imread(0,"لينك الصور")
resize_imge=cv2.resize(img,(300,400))

# %%
                              # هيظهر الصوره بقي  والاسم الي هكتله عليها
cv2.imshow("shimaa",img)

# %%
cap=cv2.VideoCapture("لينك الفديو")
                              #cv2.imshow("")
                              #هيديني ايرور لان الفديو عباره عن مجموعه من الصور الفريم يعني فلازم احدد هيعرض انهي فريم
while True:
                                #  بقرا الفريم وحالته هل هو 1 يعني فيه فريم ولا 0 مفيش اساسا
                                #  كده انا معايا الصوره عباره عن  بيكسل 
  status,frame=cap.read()
                                #بيحول الصوره لابيض واسود بينري يعني
  img_gray=  cv2.cvtColor(frame,cv2.color_BGR2GRAY)

                               # هيعرض كل مره الفريم الي عليه الدور
  cv2.imshow(" الاسم الي هيظهرلي",frame)
                                 #  بيعرض فريم كل 30 ملي ثانيه
  if cv2.waitKey(30)    & oxff ==ord("q"):    
    break                        
                              # اقفل الفديو الي فتحته واخرج من الويندوز الي اتفحت بسبب الرن

cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
img=np.zero((512,512,3))

cv2.line(img,(100,30),(400,30),(0,255,0),4)
#نقطه البدايه ونقطه النهايه وهو الوانا المستطيبل وسمكه
cv2.rectangle(img,(100,30),(400,30),(0,255,0),4)
#نقطه الاصل ونصف القطر والاولان السمك
cv2.circle(img,(210,210),50,(0,255,0),4)
cv2.PutText()


# بكتب نص علي صوره

# %%
face_detect = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")



stream = cv2.VideoCapture(0)

while True:
    
    st, frame = stream.read()

    gray_frame = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

                                                      ############# Face Detect
                                                                                          #بتاخد الصوره 
                                                                                          #SCALE يعني علي بعد قد ايه تقدر تحدد الوش

                                                                                          # 5= اطبق كام FEATURE
                                                                                          # من الالجوروم علشان اقول ان ده وش 
    faces = face_detect.detectMultiScale(gray_frame,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
        face_only = frame[y:y+h,x:x+w]
        
############# Show  
    cv2.imshow("live stream", frame)
    
    if cv2.waitKey(50) & 0xff == ord("x"):

        break

stream.release()

cv2.destroyAllWindows()
